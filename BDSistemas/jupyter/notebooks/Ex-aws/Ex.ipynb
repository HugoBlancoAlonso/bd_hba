# %% [markdown]
# # Buckt de entrada
#
# ![Foto codigo](./img/1.png)
#
# # Lambda productora
#
# ![Foto codigo](./img/2.png)
#
# ![Foto codigo](./img/3.png)
#
# # Cola principal SQS
#
# ![Foto codigo](./img/4.png)
#
# # Cola DLQ
#
# ![Foto codigo](./img/5.png)
#
# # Lambda consumidora
#
# ![Foto codigo](./img/6.png)
#
# ![Foto codigo](./img/7.png)
#
# ![Foto codigo](./img/8.png)
