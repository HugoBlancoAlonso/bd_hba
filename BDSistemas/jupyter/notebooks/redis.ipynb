# %% [markdown]
# # Introduccion a Redis
# Estos son ejercicios de conexion a redis

# %%
# !pip install redis
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 279.8/279.8 kB 4.2 MB/s eta 0:00:00 0:00:01
# ...

# %%
import redis

r = redis.Redis(
    host='redis',
    port=6379,
    db=0,
    decode_responses=True
)

# %%
r.ping()
# Out:
# True
